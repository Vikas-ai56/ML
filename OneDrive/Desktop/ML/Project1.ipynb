# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt 
import os 
import sklearn
from sklearn.preprocessing import LabelEncoder
from sklearn.cluster import KMeans

import warnings
warnings.filterwarnings("ignore")

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("rabieelkharoua/students-performance-dataset")

print("Path to dataset files:", path)
# Out:
# Path to dataset files: C:\Users\Asus\.cache\kagglehub\datasets\rabieelkharoua\students-performance-dataset\versions\2

# %%
    
# making dataframe  
df = pd.read_csv(r"C:\Users\Asus\Downloads\Student_performance_data _.csv")  
df = pd.DataFrame(dict(df))
# output the dataframe 

df
# Out:
#     StudentID  Age  Gender  Ethnicity  ParentalEducation  StudyTimeWeekly  \
# 0        1001   17       1          0                  2        19.833723
# 1        1002   18       0          0                  1        15.408756
# 2        1003   15       0          2                  3         4.210570
# 3        1004   17       1          0                  3        10.028829
# 4        1005   17       1          0                  2         4.672495
# ..        ...  ...     ...        ...                ...              ...
# 94       1095   16       1          0                  1         6.414243
# 95       1096   16       1          2                  3        19.278320
# 96       1097   16       1          1                  1        12.831594
# 97       1098   18       0          0                  2         0.468659
# 98       1099   16       0          0                  3         8.603518
#
#     Absences  Tutoring  ParentalSupport  Extracurricular  Sports  Music  \
# ...

# %%
import tensorflow as tf

# Function definition
def df_to_dataset(dataframe, shuffle=True, batch_size=32):
    original = dataframe.copy()
    labels = dataframe.pop('GradeClass')  
    ds = tf.data.Dataset.from_tensor_slices((dict(original), labels))
    if shuffle:
        ds = ds.shuffle(buffer_size=len(dataframe))
    ds = ds.batch(batch_size)
    ds = ds.prefetch(batch_size) # overlaps data preprocessing and model execution IMPROVES PERFORMANCE 
    return ds


df
# Out:
#     StudentID  Age  Gender  Ethnicity  ParentalEducation  StudyTimeWeekly  \
# 0        1001   17       1          0                  2        19.833723
# 1        1002   18       0          0                  1        15.408756
# 2        1003   15       0          2                  3         4.210570
# 3        1004   17       1          0                  3        10.028829
# 4        1005   17       1          0                  2         4.672495
# ..        ...  ...     ...        ...                ...              ...
# 94       1095   16       1          0                  1         6.414243
# 95       1096   16       1          2                  3        19.278320
# 96       1097   16       1          1                  1        12.831594
# 97       1098   18       0          0                  2         0.468659
# 98       1099   16       0          0                  3         8.603518
#
#     Absences  Tutoring  ParentalSupport  Extracurricular  Sports  Music  \
# ...

# %%
df['Age'].value_counts(normalize=True)
# Out:
# Age
# 18    0.303030
# 16    0.262626
# 17    0.242424
# 15    0.191919
# Name: proportion, dtype: float64

# %%
import sklearn.model_selection
train, test = sklearn.model_selection.train_test_split(df, test_size=0.2)
train, val = sklearn.model_selection.train_test_split(train, test_size=0.2)
train.to_csv('../ml/housing-train.csv', encoding='utf-8', index=False)
test.to_csv('../ml/housing-test.csv', encoding='utf-8', index=False)
val.to_csv('../ml/housing-val.csv', encoding='utf-8', index=False)

# %%
train_ds = df_to_dataset(train)
val_ds = df_to_dataset(val,shuffle=False, batch_size=32)
train_ds
# Out:
# <_PrefetchDataset element_spec=({'StudentID': TensorSpec(shape=(None,), dtype=tf.int64, name=None), 'Age': TensorSpec(shape=(None,), dtype=tf.int64, name=None), 'Gender': TensorSpec(shape=(None,), dtype=tf.int64, name=None), 'Ethnicity': TensorSpec(shape=(None,), dtype=tf.int64, name=None), 'ParentalEducation': TensorSpec(shape=(None,), dtype=tf.int64, name=None), 'StudyTimeWeekly': TensorSpec(shape=(None,), dtype=tf.float64, name=None), 'Absences': TensorSpec(shape=(None,), dtype=tf.int64, name=None), 'Tutoring': TensorSpec(shape=(None,), dtype=tf.int64, name=None), 'ParentalSupport': TensorSpec(shape=(None,), dtype=tf.int64, name=None), 'Extracurricular': TensorSpec(shape=(None,), dtype=tf.int64, name=None), 'Sports': TensorSpec(shape=(None,), dtype=tf.int64, name=None), 'Music': TensorSpec(shape=(None,), dtype=tf.int64, name=None), 'Volunteering': TensorSpec(shape=(None,), dtype=tf.int64, name=None), 'GPA': TensorSpec(shape=(None,), dtype=tf.float64, name=None), 'GradeClass': Tens
# ...

# %%
numericColumns = ['Age','Gender','Ethnicity','ParentalEducation','Absences','Tutoring'	
                  'Extracurricular','Sports','Music',]

# %%
from tensorflow import feature_column as fc

def get_scal(feature):
    def minmax(x):
        mini = train[feature].min()
        maxi = train[feature].max()
        return (x - mini)/(maxi-mini)
    return minmax    

inputs = {
        colname: tf.keras.layers.Input(name=colname, shape=(), dtype='float32')
        for colname in numericColumns
    }

feature_columns = dict()
for header in numericColumns:
    scal_input_fn = get_scal(header)
    feature_columns[header] = fc.numeric_column(header,normalizer_fn=scal_input_fn)

# %%
feature_layer = tf.keras.layers.Dense(feature_columns, dtype='float64')(inputs)

# `tf.keras.Sequential()` groups a linear stack of layers into a tf.keras.Model.
model = tf.keras.Sequential([
  feature_layer,
  tf.keras.layers.InputLayer(input_shape=feature_columns["Age"].shape()),
  tf.keras.layers.Dense(12, input_dim=8, activation='relu'),
  tf.keras.layers.Dense(8, activation='relu'),
  tf.keras.layers.Dense(1, activation='linear',  name='median_house_value')
])

# Model compile
model.compile(optimizer='adam',
              loss='mse',
              metrics=['mse'])

# Model Fit
history = model.fit(train_ds,
                    validation_data=val_ds,
                    epochs=32)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 feature_layer = tf.keras.layers.Dense(feature_columns, dtype='float64')(inputs)
#       3 # `tf.keras.Sequential()` groups a linear stack of layers into a tf.keras.Model.
#       4 model = tf.keras.Sequential([
#       5   feature_layer,
#       6   tf.keras.layers.InputLayer(input_shape=feature_columns["Age"].shape()),
#    (...)
#       9   tf.keras.layers.Dense(1, activation='linear',  name='median_house_value')
#      10 ])
#
# File c:\Users\Asus\OneDrive\Desktop\ML\.venv\Lib\site-packages\keras\src\utils\traceback_utils.py:122, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#     120     # To get the full stack trace, call:
#     121     # `keras.config.disable_traceback_filtering()`
# ...

# %%
model.summary()
arr = np.linspace(start=38.0, stop=42.0, num=10).tolist()
arr
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 model.summary()
#       2 arr = np.linspace(start=38.0, stop=42.0, num=10).tolist()
#       3 arr
#
# NameError: name 'model' is not defined
