# %%
'''
 Fit: The transformer learns the necessary parameters from the training data
 Transform: The transformer applies the learned parameters to the data to transform it
 Imputer : to replace missing values in a dataset with estimated values by using different strategies

Use fit_transform() only on the training data.
Use transform() on the testing data, to apply the same transformations learned from the training data.
Never: use fit_transform() on the testing data, 
as it would learn new parameters from the test data, leading to data leakage and potentially incorrect results.
'''
# Out:
# '\n Fit: The transformer learns the necessary parameters from the training data\n Transform: The transformer applies the learned parameters to the data to transform it\n\nUse fit_transform() only on the training data.\nUse transform() on the testing data, to apply the same transformations learned from the training data.\nNever: use fit_transform() on the testing data, \nas it would learn new parameters from the test data, leading to data leakage and potentially incorrect results.\n'

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt 
import os 
import sklearn
from sklearn.preprocessing import LabelEncoder
from sklearn.cluster import KMeans

# %%
train_df = pd.read_csv(r"C:\Users\Asus\Downloads\spaceship-titanic\train.csv")
test_df = pd.read_csv(r"C:\Users\Asus\Downloads\spaceship-titanic\test.csv")
y =train_df.pop('Transported')

# %%
#train_df.fillna(0,inplace=True)
train_df
# Out:
#      PassengerId HomePlanet CryoSleep     Cabin    Destination   Age    VIP  \
# 0        0001_01     Europa     False     B/0/P    TRAPPIST-1e  39.0  False
# 1        0002_01      Earth     False     F/0/S    TRAPPIST-1e  24.0  False
# 2        0003_01     Europa     False     A/0/S    TRAPPIST-1e  58.0   True
# 3        0003_02     Europa     False     A/0/S    TRAPPIST-1e  33.0  False
# 4        0004_01      Earth     False     F/1/S    TRAPPIST-1e  16.0  False
# ...          ...        ...       ...       ...            ...   ...    ...
# 8688     9276_01     Europa     False    A/98/P    55 Cancri e  41.0   True
# 8689     9278_01      Earth      True  G/1499/S  PSO J318.5-22  18.0  False
# 8690     9279_01      Earth     False  G/1500/S    TRAPPIST-1e  26.0  False
# 8691     9280_01     Europa     False   E/608/S    55 Cancri e  32.0  False
# 8692     9280_02     Europa     False   E/608/S    TRAPPIST-1e  44.0  False
#
# ...

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8693 entries, 0 to 8692
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   PassengerId   8693 non-null   object
#  1   HomePlanet    8492 non-null   object
#  2   CryoSleep     8476 non-null   object
#  3   Cabin         8494 non-null   object
#  4   Destination   8511 non-null   object
#  5   Age           8514 non-null   float64
#  6   VIP           8490 non-null   object
#  7   RoomService   8512 non-null   float64
#  8   FoodCourt     8510 non-null   float64
#  9   ShoppingMall  8485 non-null   float64
#  10  Spa           8510 non-null   float64
#  11  VRDeck        8505 non-null   float64
#  12  Name          8493 non-null   object
# dtypes: float64(6), object(7)
# memory usage: 883.0+ KB

# %%
categorical_cols = train_df.select_dtypes(include='object').columns
numerical_cols = train_df.select_dtypes(exclude='object').columns
numerical_cols.shape     

import sklearn.model_selection
import sklearn.neighbors
from sklearn.preprocessing import StandardScaler,OneHotEncoder
train_df = pd.get_dummies(train_df)
new_test_data = pd.get_dummies(test_df.drop(columns=['PassengerId']))

# Ensure test data has the same columns as train data
new_test_data = new_test_data.reindex(columns=train_df.columns, fill_value=0)

#Scale numeric features
scale = StandardScaler()
train_df = scale.fit_transform(train_df) #learn the mean and standard deviation (Refer cell-1)
new_test_data = scale.transform(new_test_data) # Note at this step only fit is used (refer cell-1)

X_train, X_val, y_train, y_val = sklearn.model_selection.train_test_split(train_df,y , test_size=0.2, random_state=42)

'''# Initialize and train the model
model = sklearn.neighbors.KNeighborsClassifier(n_neighbors=5)
model.fit(X_train, y_train)


y_pred = model.predict(X_val)
from sklearn.metrics import accuracy_score
# Evaluate the model
accuracy = accuracy_score(y_val, y_pred)
print(f'Validation Accuracy: {accuracy}')

# Predict on test data
predictions = model.predict(new_test_data)
'''
# Out:
# "# Initialize and train the model\nmodel = sklearn.neighbors.KNeighborsClassifier(n_neighbors=5)\nmodel.fit(X_train, y_train)\n\n\ny_pred = model.predict(X_val)\nfrom sklearn.metrics import accuracy_score\n# Evaluate the model\naccuracy = accuracy_score(y_val, y_pred)\nprint(f'Validation Accuracy: {accuracy}')\n\n# Predict on test data\npredictions = model.predict(new_test_data)\n"

# %%
import sklearn.compose
from sklearn.impute import SimpleImputer
import sklearn.metrics
import sklearn.model_selection
import sklearn.neighbors
from sklearn.pipeline import Pipeline

# Extract PassengerId from test data
test_passenger_ids = test_df['PassengerId']


# Preprocessing for numerical data
numerical_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='mean')),
    ('scaler', StandardScaler())
])

# Preprocessing for categorical data
categorical_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='most_frequent')),
    ('onehot', OneHotEncoder(handle_unknown='ignore'))
])

# Bundle preprocessing for numerical and categorical data
preprocessor = sklearn.compose.ColumnTransformer(
    transformers=[
        ('num', numerical_transformer, numerical_cols),
        ('cat', categorical_transformer, categorical_cols)
    ])

# Define the model
model = sklearn.neighbors.KNeighborsClassifier()

# Create and evaluate the pipeline
clf = Pipeline(steps=[('preprocessor', preprocessor),
                      ('classifier', model)])

# Split the data into training and validation sets
X_train, X_val, y_train, y_val = sklearn.model_selection.train_test_split(train_df, y, test_size=0.2, random_state=42)

# Hyperparameter tuning using GridSearchCV
param_grid = {
    'classifier__n_neighbors': [3, 5, 7, 9, 11],
    'classifier__weights': ['uniform', 'distance'],
    'classifier__metric': ['euclidean', 'manhattan']
}

grid_search =  sklearn.model_selection.GridSearchCV(clf, param_grid, cv=5, scoring='accuracy')
grid_search.fit(X_train, y_train)

# Best parameters and best score
print(f'Best parameters: {grid_search.best_params_}')
print(f'Best cross-validation accuracy: {grid_search.best_score_}')

# Evaluate the model on the validation set
best_model = grid_search.best_estimator_
y_pred = best_model.predict(X_val)

accuracy =  sklearn.metrics.accuracy_score(y_val, y_pred)
print(f'Validation Accuracy: {accuracy}')


# Predict on test data
predictions = best_model.predict(test_df)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[87], line 49
#      42 param_grid = {
#      43     'classifier__n_neighbors': [3, 5, 7, 9, 11],
#      44     'classifier__weights': ['uniform', 'distance'],
#      45     'classifier__metric': ['euclidean', 'manhattan']
#      46 }
#      48 grid_search =  sklearn.model_selection.GridSearchCV(clf, param_grid, cv=5, scoring='accuracy')
# ---> 49 grid_search.fit(X_train, y_train)
#      51 # Best parameters and best score
#      52 print(f'Best parameters: {grid_search.best_params_}')
#
# File c:\Users\Asus\OneDrive\Desktop\ML\.venv\Lib\site-packages\sklearn\base.py:1473, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1466     estimator._validate_params()
#    1468 with config_context(
#    1469     skip_parameter_validation=(
# ...
